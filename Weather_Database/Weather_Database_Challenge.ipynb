# %% [markdown]
# ## Deliverable 1. Retrieve Weather Data.
# ---
# 1. Generate a new set of 2000 random latitudes and longitudes.
# 2. Get the nearest city.
# 3. Perform an API call with the OpenWeatherMap.
# 4. Retrieve the following information from the API call.
#     - The latitude and longitude
#     - The maximum temperature
#     - The % humidity
#     - The % cloudiness
#     - The Wind speed
#     - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.
# 5. Add the data to a new DataFrame.
# 6. Save the new DataFrame as a CSV file.

# %%
from citipy import citipy
import numpy as np
import pandas as pd

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=50)
lngs = np.random.uniform(low=-180.000, high=180.000, size=50)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []


# Identify nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 41

# %%
# Import the requests library.
import requests

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ### Retrieve the following information from the API call.
#     - The latitude and longitude
#     - The Max temperature
#     - The % humidity
#     - The % cloudiness
#     - The Wind speed
#     - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
import json
import pprint

# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    print(city_url)
    city_weather = requests.get(city_url).json()
    print(city_weather)
#     print(json.dumps(city_weather, indent=4, sort_keys=True))
#     pprint.pprint(city_weather)
#     break
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
#         city_weather = requests.get(city_url).json()
#         print(json.dumps(city_weather, indent=4, sort_keys=True))
#         print(city_weather)
#         break
        
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]       
            
            # Append the City information into city_data list
        city_data.append({"City": city.title(), 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
    # If an error is experienced, skip the city

    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f6d3499013b71162bbf776ce16dd8f6a&q=new+ulm
# {'coord': {'lon': -94.4605, 'lat': 44.3125}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13d'}], 'base': 'stations', 'main': {'temp': 18.43, 'feels_like': 5.83, 'temp_min': 14.61, 'temp_max': 21.54, 'pressure': 1026, 'humidity': 78}, 'visibility': 10000, 'wind': {'speed': 12.66, 'deg': 310}, 'clouds': {'all': 90}, 'dt': 1639863720, 'sys': {'type': 2, 'id': 2041393, 'country': 'US', 'sunrise': 1639835343, 'sunset': 1639867213}, 'timezone': -21600, 'id': 5039173, 'name': 'New Ulm', 'cod': 200}
# Processing Record 1 of Set 1 | new ulm
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f6d3499013b71162bbf776ce16dd8f6a&q=atuona
# {'coord': {'lon': -139.0333, 'lat': -9.8}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 78.22, 'feels_like': 79.18, 'temp_min': 78.22, 'temp_max': 78.22, 'pressure': 1012, 'humidity': 73, 'sea_level': 1012, 'grnd_level': 1004}, 'visibility': 10000, 'wind': {'speed': 11.43, 'deg': 51, 'gust': 11.7}, 'clouds': {'all': 20}, 'dt': 1639863720, 'sys': {'country': 'PF', 'sunrise': 1639839129, 'sunset': 1639884829}, 'timezone': -34200, 'id': 4020109, 'name': 'Atuona', 'cod': 200}
# Processing Record 2 of Set 1 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f6d3499013b71162bbf776ce16dd8f6a&q=yellowknife
# {'coord': {'lon': -114.3525, 'lat': 62.456}, 'weather': [{'id': 620, 'main': 'Snow', 'description': 'light shower snow', 'icon': '13d'}], 'base': 'stations', 'main': {'temp': -12.59, 'feels_like': -25.19, 'temp_min': -16.08, 'temp_max': -12.59, 'pressure': 1029, 'humidity': 94}, 'visibility': 4828, 'wind': {'speed': 5.75, 'deg': 70}, 'clouds': {'all': 90}, 'dt': 1639863721, 'sys': {'type': 2, 'id': 2041581, 'country': 'CA', 'sunrise': 1639847106, 'sunset': 1639865002}, 'timezone': -25200, 'id': 6185377, 'name': 'Yellowknife', 'cod': 200}
# Processing Record 3 of Set 1 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f6d3499013b71162bbf776ce16dd8f6a&q=carnarvon
# {'coord': {'lon': 113.6333, 'lat': -24.8667}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 68.07, 'feels_like': 68.02, 'temp_min': 68.07, 'temp_max': 68.07, 'pressure': 1014, 'humidity': 73}, 'visibility': 10000, 'wind': {'speed': 13.8, 'deg': 160}, 'clouds': {'all': 0}, 'dt': 1639863484, 'sys': {'type': 1, 'id': 9505, 'country': 'AU', 'sunrise': 1639863125, 'sunset': 1639912371}, 'timezone': 28800, 'id': 2074865, 'name': 'Carnarvon', 'cod': 200}
# Processing Record 4 of Set 1 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f6d3499013b71162bbf776ce16dd8f6a&q=nemuro
# {'coord': {'lon': 145.575, 'lat': 43.3236}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 23.32, 'feels_like': 10.72, 'temp_min': 23.32, 'temp_max': 23.32, 'pressure': 1008, 'humidity': 59, 'sea_level': 1008, 'grnd_level': 1005}, 'visibility': 10000, 'wind': {'speed': 14.74, 'deg': 265, 'gust': 19.93}, 'clouds': {'all': 7}, 'dt': 1639863721, 'sys': {'country': 'JP', 'sunrise': 1639863937, 'sunset': 1639896221}, 'timezone': 32400, 'id': 2128975, 'name': 'Nemuro', 'cod': 200}
# Processing Record 5 of Set 1 | nemuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f6d3499013b71162bbf776ce16dd8f6a&q=cherskiy
# {'coord': {'lon': 161.3, 'lat': 68.75}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': -30.03, 'feels_like': -30.03, 'temp_min': -30.03, 'temp_max': -30.03, 'pressure': 1009, 'humidity': 95, 'sea_level': 1009, 'grnd_level': 1009}, 'visibility': 4867, 'wind': {'speed': 2.93, 'deg': 318, 'gust': 3.27}, 'clouds': {'all': 100}, 'dt': 1639863721, 'sys': {'country': 'RU', 'sunrise': 0, 'sunset': 0}, 'timezone': 39600, 'id': 2126199, 'name': 'Cherskiy', 'cod': 200}
# Processing Record 6 of Set 1 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f6d3499013b71162bbf776ce16dd8f6a&q=arraial+do+cabo
# {'coord': {'lon': -42.0278, 'lat': -22.9661}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 75.06, 'feels_like': 75.92, 'temp_min': 75.06, 'temp_max': 75.16, 'pressure': 1014, 'humidity': 78}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 130}, 'clouds': {'all': 75}, 'dt': 1639863722, 'sys': {'type': 1, 'id': 8326, 'country': 'BR', 'sunrise': 1639814314, 'sunset': 1639863066}, 'timezone': -10800, 'id': 3471451, 'name': 'Arraial do Cabo', 'cod': 200}
# Processing Record 7 of Set 1 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f6d3499013b71162bbf776ce16dd8f6a&q=kavieng
# {'coord': {'lon': 150.7967, 'lat': -2.5744}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 81.37, 'feels_like': 86.86, 'temp_min': 81.37, 'temp_max': 81.37, 'pressure': 1010, 'humidity': 78, 'sea_level': 1010, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 7.38, 'deg': 220, 'gust': 9.26}, 'rain': {'1h': 0.6}, 'clouds': {'all': 99}, 'dt': 1639863722, 'sys': {'country': 'PG', 'sunrise': 1639856741, 'sunset': 1639900911}, 'timezone': 36000, 'id': 2094342, 'name': 'Kavieng', 'cod': 200}
# Processing Record 8 of Set 1 | kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f6d3499013b71162bbf776ce16dd8f6a&q=aketi
# {'coord': {'lon': 23.7833, 'lat': 2.7388}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 73.8, 'feels_like': 74.3, 'temp_min': 73.8, 'temp_max': 73.8, 'pressure': 1011, 'humidity': 73, 'sea_level': 1011, 'grnd_level': 968}, 'visibility': 10000, 'wind': {'speed': 2.35, 'deg': 219, 'gust': 2.53}, 'clouds': {'all': 80}, 'dt': 1639863722, 'sys': {'country': 'CD', 'sunrise': 1639801358, 'sunset': 1639844423}, 'timezone': 7200, 'id': 220448, 'name': 'Aketi', 'cod': 200}
# Processing Record 9 of Set 1 | aketi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f6d3499013b71162bbf776ce16dd8f6a&q=longyearbyen
# {'coord': {'lon': 15.6401, 'lat': 78.2186}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 24.64, 'feels_like': 13.78, 'temp_min': 24.64, 'temp_max': 24.64, 'pressure': 1017, 'humidity': 80}, 'visibility': 10000, 'wind': {'speed': 11.5, 'deg': 120}, 'clouds': {'all': 0}, 'dt': 1639863723, 'sys': {'type': 1, 'id': 1663, 'country': 'SJ', 'sunrise': 0, 'sunset': 0}, 'timezone': 3600, 'id': 2729907, 'name': 'Longyearbyen', 'cod': 200}
# Processing Record 10 of Set 1 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f6d3499013b71162bbf776ce16dd8f6a&q=oranjestad
# {'coord': {'lon': -70.027, 'lat': 12.524}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 81.91, 'feels_like': 87.15, 'temp_min': 81.91, 'temp_max': 82.35, 'pressure': 1016, 'humidity': 74}, 'visibility': 10000, 'wind': {'speed': 4, 'deg': 61, 'gust': 11.01}, 'clouds': {'all': 20}, 'dt': 1639863726, 'sys': {'type': 2, 'id': 2039251, 'country': 'AW', 'sunrise': 1639824913, 'sunset': 1639865912}, 'timezone': -14400, 'id': 3577154, 'name': 'Oranjestad', 'cod': 200}
# Processing Record 11 of Set 1 | oranjestad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f6d3499013b71162bbf776ce16dd8f6a&q=westport
# {'coord': {'lon': -73.3579, 'lat': 41.1415}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 40.44, 'feels_like': 35.67, 'temp_min': 35.67, 'temp_max': 45.81, 'pressure': 1013, 'humidity': 95}, 'visibility': 10000, 'wind': {'speed': 7, 'deg': 88, 'gust': 15.99}, 'clouds': {'all': 90}, 'dt': 1639863500, 'sys': {'type': 2, 'id': 2003540, 'country': 'US', 'sunrise': 1639829633, 'sunset': 1639862791}, 'timezone': -18000, 'id': 4845585, 'name': 'Westport', 'cod': 200}
# Processing Record 12 of Set 1 | westport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f6d3499013b71162bbf776ce16dd8f6a&q=takoradi
# {'coord': {'lon': -1.7554, 'lat': 4.8845}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 81.03, 'feels_like': 86.9, 'temp_min': 81.03, 'temp_max': 81.03, 'pressure': 1011, 'humidity': 82, 'sea_level': 1011, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 9.13, 'deg': 140, 'gust': 14.05}, 'clouds': {'all': 25}, 'dt': 1639863729, 'sys': {'country': 'GH', 'sunrise': 1639807712, 'sunset': 1639850331}, 'timezone': 0, 'id': 2294915, 'name': 'Takoradze', 'cod': 200}
# Processing Record 13 of Set 1 | takoradi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f6d3499013b71162bbf776ce16dd8f6a&q=chabahar
# {'coord': {'lon': 60.643, 'lat': 25.2919}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 70.47, 'feels_like': 69.89, 'temp_min': 70.47, 'temp_max': 70.47, 'pressure': 1019, 'humidity': 57, 'sea_level': 1019, 'grnd_level': 1017}, 'visibility': 10000, 'wind': {'speed': 4.45, 'deg': 295, 'gust': 5.14}, 'clouds': {'all': 100}, 'dt': 1639863729, 'sys': {'country': 'IR', 'sunrise': 1639881458, 'sunset': 1639919481}, 'timezone': 12600, 'id': 1161724, 'name': 'Chabahar', 'cod': 200}
# Processing Record 14 of Set 1 | chabahar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f6d3499013b71162bbf776ce16dd8f6a&q=oudtshoorn
# {'coord': {'lon': 22.2014, 'lat': -33.5907}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 57.56, 'feels_like': 55.42, 'temp_min': 57.56, 'temp_max': 57.56, 'pressure': 1012, 'humidity': 51, 'sea_level': 1012, 'grnd_level': 976}, 'visibility': 10000, 'wind': {'speed': 2.95, 'deg': 57, 'gust': 3.18}, 'clouds': {'all': 100}, 'dt': 1639863730, 'sys': {'type': 1, 'id': 1918, 'country': 'ZA', 'sunrise': 1639797390, 'sunset': 1639849150}, 'timezone': 7200, 'id': 967106, 'name': 'Oudtshoorn', 'cod': 200}
# Processing Record 15 of Set 1 | oudtshoorn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f6d3499013b71162bbf776ce16dd8f6a&q=albany
# {'coord': {'lon': -73.9662, 'lat': 42.6001}, 'weather': [{'id': 601, 'main': 'Snow', 'description': 'snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': 31.28, 'feels_like': 25.56, 'temp_min': 27.7, 'temp_max': 36.81, 'pressure': 1012, 'humidity': 91}, 'visibility': 251, 'wind': {'speed': 5.77, 'deg': 130, 'gust': 18.86}, 'snow': {'1h': 0.75}, 'clouds': {'all': 100}, 'dt': 1639863730, 'sys': {'type': 2, 'id': 19530, 'country': 'US', 'sunrise': 1639830065, 'sunset': 1639862651}, 'timezone': -18000, 'id': 5106841, 'name': 'Albany', 'cod': 200}
# Processing Record 16 of Set 1 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f6d3499013b71162bbf776ce16dd8f6a&q=thompson
# {'coord': {'lon': -97.8558, 'lat': 55.7435}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': -11.04, 'feels_like': -11.04, 'temp_min': -11.04, 'temp_max': -11.04, 'pressure': 1023, 'humidity': 77}, 'visibility': 10000, 'wind': {'speed': 2.3, 'deg': 230}, 'clouds': {'all': 40}, 'dt': 1639863732, 'sys': {'type': 1, 'id': 935, 'country': 'CA', 'sunrise': 1639839469, 'sunset': 1639864718}, 'timezone': -21600, 'id': 6165406, 'name': 'Thompson', 'cod': 200}
# Processing Record 17 of Set 1 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f6d3499013b71162bbf776ce16dd8f6a&q=hobart
# {'coord': {'lon': 147.3294, 'lat': -42.8794}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 63.55, 'feels_like': 62.29, 'temp_min': 62.06, 'temp_max': 68.02, 'pressure': 995, 'humidity': 57}, 'visibility': 10000, 'wind': {'speed': 1.99, 'deg': 45, 'gust': 3}, 'clouds': {'all': 40}, 'dt': 1639863583, 'sys': {'type': 2, 'id': 2002195, 'country': 'AU', 'sunrise': 1639852044, 'sunset': 1639907272}, 'timezone': 39600, 'id': 2163355, 'name': 'Hobart', 'cod': 200}
# Processing Record 18 of Set 1 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f6d3499013b71162bbf776ce16dd8f6a&q=marsa+matruh
# {'coord': {'lon': 27.2453, 'lat': 31.3525}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 55.6, 'feels_like': 54.43, 'temp_min': 55.6, 'temp_max': 55.6, 'pressure': 1013, 'humidity': 76}, 'visibility': 10000, 'wind': {'speed': 18.41, 'deg': 230}, 'clouds': {'all': 20}, 'dt': 1639863732, 'sys': {'type': 1, 'id': 2517, 'country': 'EG', 'sunrise': 1639803864, 'sunset': 1639840255}, 'timezone': 7200, 'id': 352733, 'name': 'Marsá Maţrūḩ', 'cod': 200}
# Processing Record 19 of Set 1 | marsa matruh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f6d3499013b71162bbf776ce16dd8f6a&q=samusu
# {'cod': '404', 'message': 'city not found'}
# Processing Record 20 of Set 1 | samusu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f6d3499013b71162bbf776ce16dd8f6a&q=manoel+urbano
# {'coord': {'lon': -69.2597, 'lat': -8.8389}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 79.18, 'feels_like': 79.18, 'temp_min': 79.18, 'temp_max': 79.18, 'pressure': 1006, 'humidity': 96, 'sea_level': 1006, 'grnd_level': 989}, 'visibility': 10000, 'wind': {'speed': 1.95, 'deg': 289, 'gust': 2.24}, 'clouds': {'all': 98}, 'dt': 1639863735, 'sys': {'country': 'BR', 'sunrise': 1639822482, 'sunset': 1639867974}, 'timezone': -18000, 'id': 3663495, 'name': 'Manoel Urbano', 'cod': 200}
# Processing Record 21 of Set 1 | manoel urbano
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f6d3499013b71162bbf776ce16dd8f6a&q=poum
# {'coord': {'lon': 164.0167, 'lat': -20.2333}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 77.97, 'feels_like': 78.76, 'temp_min': 77.97, 'temp_max': 77.97, 'pressure': 1012, 'humidity': 70, 'sea_level': 1012, 'grnd_level': 1012}, 'visibility': 10000, 'wind': {'speed': 7.2, 'deg': 138, 'gust': 8.75}, 'clouds': {'all': 8}, 'dt': 1639863736, 'sys': {'country': 'NC', 'sunrise': 1639851614, 'sunset': 1639899690}, 'timezone': 39600, 'id': 2138555, 'name': 'Poum', 'cod': 200}
# Processing Record 22 of Set 1 | poum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f6d3499013b71162bbf776ce16dd8f6a&q=berlevag
# {'coord': {'lon': 29.0864, 'lat': 70.8578}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': 31.51, 'feels_like': 20.14, 'temp_min': 31.51, 'temp_max': 31.51, 'pressure': 1000, 'humidity': 89, 'sea_level': 1000, 'grnd_level': 999}, 'visibility': 7932, 'wind': {'speed': 17.4, 'deg': 120, 'gust': 17.36}, 'snow': {'1h': 0.11}, 'clouds': {'all': 100}, 'dt': 1639863736, 'sys': {'country': 'NO', 'sunrise': 0, 'sunset': 0}, 'timezone': 3600, 'id': 780687, 'name': 'Berlevåg', 'cod': 200}
# Processing Record 23 of Set 1 | berlevag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f6d3499013b71162bbf776ce16dd8f6a&q=qaanaaq
# {'coord': {'lon': -69.3632, 'lat': 77.484}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 3.58, 'feels_like': -8.12, 'temp_min': 3.58, 'temp_max': 3.58, 'pressure': 1016, 'humidity': 71, 'sea_level': 1016, 'grnd_level': 1011}, 'visibility': 10000, 'wind': {'speed': 6.42, 'deg': 43, 'gust': 5.99}, 'clouds': {'all': 99}, 'dt': 1639863737, 'sys': {'country': 'GL', 'sunrise': 0, 'sunset': 0}, 'timezone': -14400, 'id': 3831208, 'name': 'Qaanaaq', 'cod': 200}
# Processing Record 24 of Set 1 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f6d3499013b71162bbf776ce16dd8f6a&q=bethel
# {'coord': {'lon': -73.414, 'lat': 41.3712}, 'weather': [{'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50n'}], 'base': 'stations', 'main': {'temp': 37.31, 'feels_like': 35.33, 'temp_min': 33.49, 'temp_max': 41.99, 'pressure': 1013, 'humidity': 90}, 'visibility': 4023, 'wind': {'speed': 3, 'deg': 110, 'gust': 5.99}, 'clouds': {'all': 90}, 'dt': 1639863556, 'sys': {'type': 2, 'id': 2008903, 'country': 'US', 'sunrise': 1639829690, 'sunset': 1639862761}, 'timezone': -18000, 'id': 5282297, 'name': 'Bethel', 'cod': 200}
# Processing Record 25 of Set 1 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f6d3499013b71162bbf776ce16dd8f6a&q=punta+arenas
# {'coord': {'lon': -70.9167, 'lat': -53.15}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 69.91, 'feels_like': 68.49, 'temp_min': 69.91, 'temp_max': 69.91, 'pressure': 1006, 'humidity': 40}, 'visibility': 10000, 'wind': {'speed': 25.32, 'deg': 260}, 'clouds': {'all': 0}, 'dt': 1639863737, 'sys': {'type': 1, 'id': 8487, 'country': 'CL', 'sunrise': 1639815114, 'sunset': 1639876138}, 'timezone': -10800, 'id': 3874787, 'name': 'Punta Arenas', 'cod': 200}
# Processing Record 26 of Set 1 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f6d3499013b71162bbf776ce16dd8f6a&q=ponta+do+sol
# {'coord': {'lon': -17.1, 'lat': 32.6667}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 64.53, 'feels_like': 64.29, 'temp_min': 64.13, 'temp_max': 66.83, 'pressure': 1013, 'humidity': 77, 'sea_level': 1013, 'grnd_level': 1013}, 'visibility': 10000, 'wind': {'speed': 12.66, 'deg': 170, 'gust': 16.71}, 'clouds': {'all': 53}, 'dt': 1639863738, 'sys': {'type': 2, 'id': 2008291, 'country': 'PT', 'sunrise': 1639814703, 'sunset': 1639850708}, 'timezone': 0, 'id': 2264557, 'name': 'Ponta do Sol', 'cod': 200}
# Processing Record 27 of Set 1 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f6d3499013b71162bbf776ce16dd8f6a&q=cape+town
# {'coord': {'lon': 18.4232, 'lat': -33.9258}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 64.92, 'feels_like': 64.54, 'temp_min': 63.1, 'temp_max': 69.12, 'pressure': 1012, 'humidity': 73}, 'visibility': 10000, 'wind': {'speed': 1.01, 'deg': 0, 'gust': 1.99}, 'clouds': {'all': 0}, 'dt': 1639863732, 'sys': {'type': 2, 'id': 2033665, 'country': 'ZA', 'sunrise': 1639798243, 'sunset': 1639850111}, 'timezone': 7200, 'id': 3369157, 'name': 'Cape Town', 'cod': 200}
# Processing Record 28 of Set 1 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f6d3499013b71162bbf776ce16dd8f6a&q=butaritari
# {'coord': {'lon': 172.7902, 'lat': 3.0707}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 82, 'feels_like': 88.81, 'temp_min': 82, 'temp_max': 82, 'pressure': 1010, 'humidity': 80, 'sea_level': 1010, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 17.4, 'deg': 77, 'gust': 19.48}, 'rain': {'1h': 0.47}, 'clouds': {'all': 83}, 'dt': 1639863738, 'sys': {'country': 'KI', 'sunrise': 1639852047, 'sunset': 1639895044}, 'timezone': 43200, 'id': 2110227, 'name': 'Butaritari', 'cod': 200}
# Processing Record 29 of Set 1 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f6d3499013b71162bbf776ce16dd8f6a&q=iqaluit
# {'coord': {'lon': -68.5145, 'lat': 63.7506}, 'weather': [{'id': 601, 'main': 'Snow', 'description': 'snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': 13.73, 'feels_like': 1.13, 'temp_min': 13.73, 'temp_max': 13.73, 'pressure': 990, 'humidity': 92}, 'visibility': 1207, 'wind': {'speed': 29.93, 'deg': 320}, 'snow': {'1h': 0.76}, 'clouds': {'all': 90}, 'dt': 1639863739, 'sys': {'type': 1, 'id': 797, 'country': 'CA', 'sunrise': 1639837207, 'sunset': 1639852891}, 'timezone': -18000, 'id': 5983720, 'name': 'Iqaluit', 'cod': 200}
# Processing Record 30 of Set 1 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f6d3499013b71162bbf776ce16dd8f6a&q=tasiilaq
# {'coord': {'lon': -37.6368, 'lat': 65.6145}, 'weather': [{'id': 601, 'main': 'Snow', 'description': 'snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': 30.36, 'feels_like': 17.76, 'temp_min': 30.36, 'temp_max': 30.36, 'pressure': 1023, 'humidity': 92, 'sea_level': 1023, 'grnd_level': 1018}, 'visibility': 352, 'wind': {'speed': 31.18, 'deg': 73, 'gust': 53.33}, 'snow': {'1h': 0.52}, 'clouds': {'all': 100}, 'dt': 1639863739, 'sys': {'type': 1, 'id': 81, 'country': 'GL', 'sunrise': 1639831966, 'sunset': 1639843306}, 'timezone': -10800, 'id': 3424607, 'name': 'Tasiilaq', 'cod': 200}
# Processing Record 31 of Set 1 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f6d3499013b71162bbf776ce16dd8f6a&q=attawapiskat
# {'cod': '404', 'message': 'city not found'}
# Processing Record 32 of Set 1 | attawapiskat
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f6d3499013b71162bbf776ce16dd8f6a&q=sibolga
# {'coord': {'lon': 98.7792, 'lat': 1.7427}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 73.76, 'feels_like': 75.4, 'temp_min': 73.76, 'temp_max': 73.76, 'pressure': 1011, 'humidity': 97, 'sea_level': 1011, 'grnd_level': 1010}, 'visibility': 4538, 'wind': {'speed': 3.33, 'deg': 316, 'gust': 4.43}, 'clouds': {'all': 100}, 'dt': 1639863740, 'sys': {'country': 'ID', 'sunrise': 1639869678, 'sunset': 1639912950}, 'timezone': 25200, 'id': 1213855, 'name': 'Sibolga', 'cod': 200}
# Processing Record 33 of Set 1 | sibolga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f6d3499013b71162bbf776ce16dd8f6a&q=rikitea
# {'coord': {'lon': -134.9692, 'lat': -23.1203}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 77.54, 'feels_like': 78.57, 'temp_min': 77.54, 'temp_max': 77.54, 'pressure': 1013, 'humidity': 76, 'sea_level': 1013, 'grnd_level': 1011}, 'visibility': 10000, 'wind': {'speed': 7.38, 'deg': 21, 'gust': 8.46}, 'rain': {'1h': 0.7}, 'clouds': {'all': 85}, 'dt': 1639863740, 'sys': {'country': 'PF', 'sunrise': 1639836607, 'sunset': 1639885400}, 'timezone': -32400, 'id': 4030556, 'name': 'Rikitea', 'cod': 200}
# Processing Record 34 of Set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f6d3499013b71162bbf776ce16dd8f6a&q=jamestown
# {'coord': {'lon': -79.2353, 'lat': 42.097}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}, {'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50d'}], 'base': 'stations', 'main': {'temp': 39.49, 'feels_like': 35.15, 'temp_min': 32.52, 'temp_max': 43.92, 'pressure': 1007, 'humidity': 98}, 'visibility': 4023, 'wind': {'speed': 5.99, 'deg': 318, 'gust': 11.01}, 'rain': {'1h': 0.22}, 'clouds': {'all': 90}, 'dt': 1639863740, 'sys': {'type': 2, 'id': 2008828, 'country': 'US', 'sunrise': 1639831230, 'sunset': 1639864016}, 'timezone': -18000, 'id': 5122534, 'name': 'Jamestown', 'cod': 200}
# Processing Record 35 of Set 1 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f6d3499013b71162bbf776ce16dd8f6a&q=mount+isa
# {'coord': {'lon': 139.5, 'lat': -20.7333}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 80.37, 'feels_like': 83.41, 'temp_min': 80.37, 'temp_max': 80.37, 'pressure': 1011, 'humidity': 69}, 'visibility': 10000, 'wind': {'speed': 0, 'deg': 0}, 'clouds': {'all': 1}, 'dt': 1639863741, 'sys': {'type': 1, 'id': 9495, 'country': 'AU', 'sunrise': 1639857439, 'sunset': 1639905637}, 'timezone': 36000, 'id': 2065594, 'name': 'Mount Isa', 'cod': 200}
# Processing Record 36 of Set 1 | mount isa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f6d3499013b71162bbf776ce16dd8f6a&q=glenwood+springs
# {'coord': {'lon': -107.3248, 'lat': 39.5505}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 31.89, 'feels_like': 27.32, 'temp_min': 25.61, 'temp_max': 34.83, 'pressure': 1024, 'humidity': 48}, 'visibility': 10000, 'wind': {'speed': 4.61, 'deg': 240}, 'clouds': {'all': 1}, 'dt': 1639863556, 'sys': {'type': 1, 'id': 3027, 'country': 'US', 'sunrise': 1639837492, 'sunset': 1639871242}, 'timezone': -25200, 'id': 5423092, 'name': 'Glenwood Springs', 'cod': 200}
# Processing Record 37 of Set 1 | glenwood springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f6d3499013b71162bbf776ce16dd8f6a&q=chokurdakh
# {'coord': {'lon': 147.9167, 'lat': 70.6333}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': -34.83, 'feels_like': -47.43, 'temp_min': -34.83, 'temp_max': -34.83, 'pressure': 1012, 'humidity': 100, 'sea_level': 1012, 'grnd_level': 1008}, 'visibility': 3743, 'wind': {'speed': 3.67, 'deg': 192, 'gust': 3.51}, 'clouds': {'all': 97}, 'dt': 1639863741, 'sys': {'country': 'RU', 'sunrise': 0, 'sunset': 0}, 'timezone': 39600, 'id': 2126123, 'name': 'Chokurdakh', 'cod': 200}
# Processing Record 38 of Set 1 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f6d3499013b71162bbf776ce16dd8f6a&q=port+alfred
# {'coord': {'lon': 26.891, 'lat': -33.5906}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 65.19, 'feels_like': 64.98, 'temp_min': 65.19, 'temp_max': 65.19, 'pressure': 1016, 'humidity': 76, 'sea_level': 1016, 'grnd_level': 1014}, 'visibility': 10000, 'wind': {'speed': 23.85, 'deg': 57, 'gust': 36.22}, 'clouds': {'all': 14}, 'dt': 1639863742, 'sys': {'country': 'ZA', 'sunrise': 1639796264, 'sunset': 1639848024}, 'timezone': 7200, 'id': 964432, 'name': 'Port Alfred', 'cod': 200}
# Processing Record 39 of Set 1 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f6d3499013b71162bbf776ce16dd8f6a&q=ushuaia
# {'coord': {'lon': -68.3, 'lat': -54.8}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 64.06, 'feels_like': 62.28, 'temp_min': 64.06, 'temp_max': 64.06, 'pressure': 1002, 'humidity': 45}, 'visibility': 10000, 'wind': {'speed': 17.27, 'deg': 230}, 'clouds': {'all': 20}, 'dt': 1639863508, 'sys': {'type': 1, 'id': 8303, 'country': 'AR', 'sunrise': 1639813834, 'sunset': 1639876162}, 'timezone': -10800, 'id': 3833367, 'name': 'Ushuaia', 'cod': 200}
# Processing Record 40 of Set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f6d3499013b71162bbf776ce16dd8f6a&q=ekhabi
# {'coord': {'lon': 142.9671, 'lat': 53.5102}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': -5.6, 'feels_like': -18.2, 'temp_min': -5.6, 'temp_max': -5.6, 'pressure': 1002, 'humidity': 88, 'sea_level': 1002, 'grnd_level': 999}, 'visibility': 10000, 'wind': {'speed': 13.44, 'deg': 261, 'gust': 24.18}, 'clouds': {'all': 100}, 'dt': 1639863742, 'sys': {'country': 'RU', 'sunrise': 1639867257, 'sunset': 1639894153}, 'timezone': 39600, 'id': 2122614, 'name': 'Ekhabi', 'cod': 200}
# Processing Record 41 of Set 1 | ekhabi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 39

# %%
# Convert array of dictionaries to a pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp Current Description  Humidity  \
# 0          New Ulm  44.3125  -94.4605     21.54          light snow        78
# 1           Atuona  -9.8000 -139.0333     78.22          few clouds        73
# 2      Yellowknife  62.4560 -114.3525    -12.59   light shower snow        94
# 3        Carnarvon -24.8667  113.6333     68.07           clear sky        73
# 4           Nemuro  43.3236  145.5750     23.32           clear sky        59
# 5         Cherskiy  68.7500  161.3000    -30.03     overcast clouds        95
# 6  Arraial Do Cabo -22.9661  -42.0278     75.16       broken clouds        78
# 7          Kavieng  -2.5744  150.7967     81.37          light rain        78
# 8            Aketi   2.7388   23.7833     73.80       broken clouds        73
# 9     Longyearbyen  78.2186   15.6401     24.64           clear sky        80
#
#    Cloudiness  Wind Speed Country
# 0          90       12.66      US
# 1          20       11.43      PF
# 2          90        5.75      CA
# 3           0       13.80      AU
# 4           7       14.74      JP
# 5         100        2.93      RU
# 6          75        8.05      BR
# 7          99        7.38      PG
# 8          80        2.35      CD
# 9           0       11.50      SJ

# %%
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Reorder the columns in the order you want them to appear.
new_column_order = ["City", "Country", "Lat",
                    "Lng", "Max Temp", "Humidity", 
                    "Cloudiness", "Wind Speed", 
                    "Current Description"] 

# Assign a new or the same DataFrame the new column order.
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          New Ulm      US  44.3125  -94.4605     21.54        78          90
# 1           Atuona      PF  -9.8000 -139.0333     78.22        73          20
# 2      Yellowknife      CA  62.4560 -114.3525    -12.59        94          90
# 3        Carnarvon      AU -24.8667  113.6333     68.07        73           0
# 4           Nemuro      JP  43.3236  145.5750     23.32        59           7
# 5         Cherskiy      RU  68.7500  161.3000    -30.03        95         100
# 6  Arraial Do Cabo      BR -22.9661  -42.0278     75.16        78          75
# 7          Kavieng      PG  -2.5744  150.7967     81.37        78          99
# 8            Aketi      CD   2.7388   23.7833     73.80        73          80
# 9     Longyearbyen      SJ  78.2186   15.6401     24.64        80           0
#
#    Wind Speed Current Description
# 0       12.66          light snow
# 1       11.43          few clouds
# 2        5.75   light shower snow
# 3       13.80           clear sky
# 4       14.74           clear sky
# 5        2.93     overcast clouds
# 6        8.05       broken clouds
# 7        7.38          light rain
# 8        2.35       broken clouds
# 9       11.50           clear sky

# %%
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %%
# Create the output File (CSV)
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the city_data into a csv
city_data_df.to_csv(output_data_file, index_label="City_ID")
